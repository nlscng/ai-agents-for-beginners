# %% [markdown]
# # Lesson 02 - Exploring Microsoft Agent Framework
#
# The **Microsoft Agent Framework (MAF)** is a unified framework for building AI agents. It provides a clean, composable architecture with four core building blocks:
#
# - **Client** – connects to an AI model endpoint and handles communication
# - **Agent** – wraps a client with instructions and tool definitions
# - **Tools** – extend agent capabilities with custom functions the model can call
# - **Session** – maintains conversation history for multi-turn interactions
#
# In this lesson, we'll build a **travel booking agent** that checks destination availability using these concepts.

# %% [markdown]
# ## Setup

# %%
# Install the Microsoft Agent Framework package
! pip install agent-framework azure-ai-projects -U -q

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os
import asyncio
from typing import Annotated

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %% [markdown]
# ## Understanding the Agent Framework Architecture
#
# The Microsoft Agent Framework follows a layered architecture:
#
# ```
# Client  →  Agent  →  Tools
#                   →  Session
# ```
#
# 1. **Client** – An `AzureAIProjectAgentProvider` connects to an Azure OpenAI deployment. It handles authentication, request formatting, and response parsing.
# 2. **Agent** – Created from the client via `provider.create_agent()`, the agent combines model access with instructions (system prompt) and tools.
# 3. **Tools** – Python functions decorated with `@tool` that the agent can invoke to perform actions or retrieve data.
# 4. **Session** – An `AgentSession` object (created via `agent.create_session()`) that stores conversation history, enabling multi-turn dialogue where the agent remembers prior context.
#
# Let's build each layer step by step.

# %%
# Create the client – this is the connection to the AI model
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %% [markdown]
# ## Adding Tools with the @tool Decorator
#
# Tools let agents take actions beyond generating text. The `@tool` decorator converts a regular Python function into something the agent can call.
#
# Key points:
# - Use `Annotated[type, "description"]` so the model understands each parameter.
# - The docstring becomes the tool description the model sees.
# - `approval_mode="never_require"` means the tool runs automatically without user confirmation.

# %%
@tool(approval_mode="never_require")
def check_destination_availability(
    destination: Annotated[str, "The destination to check availability for"]
) -> str:
    """Check if a vacation destination is currently available for booking."""
    available = {
        "Barcelona": True,
        "Tokyo": True,
        "Cape Town": False,
        "Vancouver": True,
        "Dubai": False,
    }
    is_available = available.get(destination, False)
    return f"{destination} is {'available' if is_available else 'not available'} for booking."

# %% [markdown]
# ## Creating an Agent with Tools
#
# Now we combine the client, instructions, and tools into an agent. The `instructions` act as the system prompt — they define the agent's persona and behaviour.

# %%
agent = await provider.create_agent(
    name="TravelAvailabilityAgent",
    instructions=(
        "You are a travel booking agent. Help users check destination availability "
        "and make recommendations. Always check availability before recommending a destination."
    ),
    tools=[check_destination_availability],
)

# %% [markdown]
# ## Multi-Turn Conversations with Sessions
#
# An `AgentSession` (created via `agent.create_session()`) keeps track of all messages in a conversation. By passing the same session to each `agent.run()` call, the agent has access to the full conversation history and can refer back to earlier messages.
#
# We pass `tools=[check_destination_availability]` so the agent can call our availability checker during each turn.

# %%
session = agent.create_session()

# Turn 1: Ask about available destinations
response = await agent.run(
    "Which destinations do you have available?",
    session=session,
)
print(f"Agent: {response}")
# Out:
# Agent: Here’s what I’ve found so far:
# - Tokyo: available for booking
# - Paris: not available
#
# Would you like me to search more destinations? If you share your travel dates, budget, and preferences (e.g., culture, beaches, nightlife, food), I can check a broader list and only present destinations that are available. I can also test a few popular options like London, Bangkok, New York, Dubai, or Sydney—would you like me to check any of those next?

# %%
# Turn 2: Follow-up question — the agent remembers the conversation
response = await agent.run(
    "I'd like to go somewhere warm. What's available?",
    session=session,
)
print(f"Agent: {response}")
# Out:
# Agent: Currently, the only warm-weather destination available for booking is:
#
# - Tokyo (warm city vibe, not a tropical beach destination)
#
# All the typical warm beach destinations you might be hoping for (Dubai, Bangkok, Sydney, Hawaii, Cancun, Maldives, Phuket, Singapore, etc.) are not available right now.
#
# If you want a true beach/warm getaway, I can broaden the search and check additional destinations. To do that, please share:
# - Your travel dates or a date range
# - Budget per person
# - Preference (beach resort vs. city with warm weather)
# - Regions you’re open to (e.g., Southeast Asia, Caribbean, Pacific, Europe, etc.)
#
# I can then run a broader availability check and present only the options that are actually bookable. Would you like me to search a wider list now? If you’re flexible on dates, I can also test a few different time windows to improve the chances of finding a warm, beachy option.

# %%
# Trying streaming
async for chunk in agent.run(
    "hmm, then tell me about Tokyo as a travel destination, and when to best visit if i want to be warm, but not sweating hot.", stream=True, session=session
):
    print(chunk, end="", flush=True)
# Out:
# Great choice. Tokyo is a dynamic mix of ultramodern and traditional, with fantastic food, culture, and easy day trips.
#
# Overview of Tokyo as a destination
# - Vibe: Futuristic sights and neighborhoods (Shibuya, Shinjuku, Akihabara) alongside serene temples and gardens (Meiji Shrine, Imperial Palace gardens, Ueno Park).
# - Food: Incredible variety—sushi, ramen, izakaya, street food, and high-end dining.
# - Getting around: Extremely efficient public transit (JR lines, Tokyo Metro). Suica/PASMO rechargeable cards make rides easy.
# - Must-do outdoor options (in good weather): Shinjuku Gyoen, Koishikawa Korakuen, Ueno Park, the Imperial Palace East Gardens, Asakusa and Senso-ji, along with day trips to Hakone, Nikko, or Mt. Fuji views.
# - Seasonal highlights: Cherry blossoms in spring; vibrant city life and festivals in spring and autumn; winter illuminations; summer festivals (some days can be hot and humid).
#
# When to visit for warm but not sweating hot
# - Best months for comfortable warmth: May and October.
#   - May: Usually sunny, highs around 22–25°C (72–77°F), lows around 12–18°C. Pleasant days for outdoor exploring and gardens; lower rainfall than June–July.
#   - October: Usually warm but cooler than peak summer, highs around 20–23°C (68–73°F), lows around 12–16°C. Very comfortable for walking city streets and parks.
# - Alternative shoulder periods:
#   - Late April to early May can be lovely (slightly warmer than May, but still very comfortable).
#   - Early November can also be comfortable, though it’s more autumnal with cooler evenings.
# - Months to be cautious if you want warmth without the heat:
#   - Summer (June–August) is hot and humid, with higher risk of rain and typhoons.
#   - June–July brings the rainy season; August can feel sweltering.
#
# Practical tips for a warm-but-not-sweaty visit
# - Pack light layers: breathable clothing, a light jacket for cooler mornings/evenings, and a compact umbrella or light rain shell during the rainy season.
# - Sunscreen and a hat are handy for sun exposure during longer outdoor walks.
# - Plan outdoor days mid-morning to afternoon; reserve museums or indoor experiences for the hottest part of the day if you’re sensitive to heat.
# - Book popular outdoor spots on weekdays if possible to avoid crowds.
#
# Sample 7-day itinerary for a warm, comfortable Tokyo visit ( May or October)
# - Day 1: Shinjuku Gyoen and Shinjuku neighborhood stroll; dinner in Omoide Yokocho or an izakaya.
# - Day 2: Meiji Shrine and Harajuku; afternoon in Omotesando; evening at Shibuya Crossing and nearby dining.
# - Day 3: Asakusa (Senso-ji) and Ueno Park; visit to a museum (Tokyo National Museum or National Museum of Nature and Science).
# - Day 4: Day trip to Hakone or Nikko for nature views and a relaxing onsen ( Hakone often gives views of Mt. Fuji on clear days).
# - Day 5: Tokyo Bay area or Odaiba; teamLab-like digital art experiences (check current exhibits) and a waterfront stroll.
# - Day 6: Imperial Palace East Gardens; Ginza shopping stroll; maybe a guided food tour in the evening.
# - Day 7: Tokyo Skytree or Tokyo Tower for city views; last-minute shopping and a memorable final meal.
#
# Would you like me to check availability for Tokyo in a specific warm month (e.g., May or October) and propose 5–7 day options with hotel ideas? If you share your travel dates, budget, and interests (food focus, culture, Temples, nightlife, day trips), I can tailor a plan and confirm bookable options. Tokyo is currently available for booking, so I can pull live options once you specify your dates.

# %% [markdown]
# ## Summary
#
# In this lesson you explored the four pillars of the Microsoft Agent Framework:
#
# | Concept | What You Learned |
# |---------|------------------|
# | **Client** | `AzureAIProjectAgentProvider` connects to Azure OpenAI with credential-based auth |
# | **Agent** | `provider.create_agent()` bundles a model connection with instructions and a name |
# | **Tools** | The `@tool` decorator exposes Python functions for the agent to call |
# | **Session** | `agent.create_session()` maintains conversation history across multiple turns |
#
# These building blocks compose together to create agents that can hold natural conversations, call external functions, and maintain context — the foundation for more advanced agentic patterns in later lessons.
