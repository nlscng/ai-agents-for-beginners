# %% [markdown]
# # Lesson 01 - Introduction to AI Agents
#
# Welcome to the first lesson in the **AI Agents for Beginners** course!
#
# An **AI agent** is a program that uses a large language model (LLM) as its reasoning engine and can take *actions* in the real world — calling APIs, querying databases, or running code — to accomplish a goal on behalf of a user.
#
# In this notebook you will build your first agent: a **Travel Agent** that recommends vacation destinations. Along the way you will learn how to:
#
# 1. Connect to Azure AI Foundry Agent Service using the **Microsoft Agent Framework**.
# 2. Give the agent a **tool** — a plain Python function it can call.
# 3. Run the agent and inspect its response.
# 4. Stream the agent's response token-by-token.

# %% [markdown]
# ## Setup
#
# Before running this notebook, make sure you have:
#
# 1. **An Azure AI Foundry project** with a deployed chat model (e.g. `gpt-4o-mini`).
# 2. **Logged in with the Azure CLI** — run `az login` in your terminal.
# 3. **Set the required environment variables:**
#    - `AZURE_AI_PROJECT_ENDPOINT` — your Azure AI Foundry project endpoint.
#    - `AZURE_AI_MODEL_DEPLOYMENT_NAME` — the name of your deployed model.
#
# The cell below installs the Python packages you need.

# %%
# %pip install agent-framework azure-ai-projects azure-identity -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os
import asyncio
from typing import Annotated

from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       5 import asyncio
#       6 from typing import Annotated
# ----> 8 from agent_framework import tool
#       9 from agent_framework.azure import AzureAIProjectAgentProvider
#      10 from azure.identity import AzureCliCredential
#
# ModuleNotFoundError: No module named 'agent_framework'

# %% [markdown]
# ## Creating Your First Agent
#
# An agent needs two things:
#
# - **Instructions** that tell it *who it is* and *how to behave* (a system prompt).
# - **Tools** — Python functions decorated with `@tool` that the agent can call to retrieve information or perform actions.
#
# Below we define a simple tool that returns a list of popular vacation destinations. The agent will use this tool when a user asks for travel recommendations.

# %%
@tool(approval_mode="never_require")
async def get_destinations() -> list[str]:
    """Get a list of popular vacation destinations."""
    return [
        "Barcelona",
        "Paris",
        "Berlin",
        "Tokyo",
        "Sydney",
        "New York City",
        "Cairo",
        "Cape Town",
        "Rio de Janeiro",
        "Bali",
    ]

# %%
agent = await provider.create_agent(
    tools=[get_destinations],
    name="TravelAgent",
    instructions=(
        "You are a helpful travel agent. Help users find their perfect vacation "
        "destination based on their preferences. Use the get_destinations tool "
        "to see available destinations."
    ),
)

response = await agent.run(
    "I'm looking for a warm beach destination. What do you recommend?"
)
print(response)
# Out:
# Great pick—there are several warm-beach options in your list. Here are the top picks for a sun-soaked getaway:
#
# - Bali, Indonesia
#   - Vibe: Tropical paradise with white-sand beaches, crystal-clear water, great s-cene of temples, and lush scenery.
#   - Why it’s great for a warm beach vacation: consistently warm temperatures, amazing snorkeling/diving, plenty of beach clubs and spa options, family-friendly to adults-only.
#   - Quick tips: March is the tail end of the wet season (brief showers possible) but still warm. Best areas: Seminyak/Legian (lively), Nusa Dua (calm and family-friendly), Uluwatu (sweeping ocean views).
#   - Ideal for: relaxation, culture, couples retreats, families.
#
# - Rio de Janeiro, Brazil
#   - Vibe: Iconic beach culture with Copacabana and Ipanema, vibrant music, and stunning natural backdrop.
#   - Why it’s great for a warm beach vacation: hot, sunny weather; lively beach scene; easy access to day trips (Sugarloaf, Christ the Redeemer).
#   - Quick tips: March is hot and humid; stay aware of your surroundings in crowded areas; Portuguese basics go a long way.
#   - Ideal for: social/party vibe, outdoor activities, photography, nightlife.
#
# - Sydney, Australia
#   - Vibe: Beautiful urban-beach mix with famous surf beaches like Bondi and Manly, plus great dining and city exploration.
#   - Why it’s great for a warm beach vacation: late summer warmth, great beaches, safe and well-developed infrastructure.
#   - Quick tips: Beach culture is strong; water can be chilly by some standards but still pleasant; plenty of sun, surf, and scenery.
#   - Ideal for: a balance of city and beach, family trips, surfing beginners, scenic coastal walks.
#
# Would you like me to tailor one of these to your dates, budget, and vibe? For example:
# - Duration and travel window (how many days, when are you thinking of going)?
# - Group type (romantic couple, family, friends)?
# - Budget range (mid-range, luxury, or something in between)?
# - Must-haves (surfing, snorkeling, spa days, nightlife, cultural sites)?
# - Preference on flight time/distance (shorter flights vs. one-stop longer trips)?
#
# Tell me a bit about your priorities, and I’ll refine to one or two concrete itineraries with sample day-by-day plans and rough costs.

# %% [markdown]
# ## Streaming Responses
#
# For a more interactive experience you can **stream** the agent's response. Instead of waiting for the full reply, the agent yields text chunks as they are generated. This is especially useful in chat interfaces where you want to display output in real time.

# %%
async for chunk in agent.run(
    "Tell me about Tokyo as a travel destination", stream=True
):
    print(chunk, end="", flush=True)
# Out:
# Tokyo is a standout travel destination because it mixes ultra-modern energy with deep traditional roots. It’s a sprawling metropolis where neon-lit nightlife sits beside tranquil temples, and where world-class food, fashion, and tech sit shoulder to shoulder with centuries of history.
#
# Key reasons to visit
# - Endless contrasts: cutting-edge architecture and design with centuries-old shrines and gardens.
# - Food paradise: sushi, ramen, tempura, yakitori, street food, and incredible department-store food halls (depachika).
# - Efficient transport: clean, punctual trains and a convenient IC card system (Suica/PASMO) make hopping around easy.
# - Safe and welcoming: very safe for travelers, with helpful locals and abundant signage in English in tourist areas.
#
# Neighborhood vibes to explore
# - Shinjuku: buzzing nightlife, tall skyscrapers, and the noise of the city; great for shopping and dining.
# - Shibuya: famous crossing, youth culture, fashion, and vibrant street life.
# - Asakusa: traditional vibe, Senso-ji temple, and charming old-town streets.
# - Ginza: upscale shopping, fine dining, and chic department stores.
# - Harajuku/Omotesando: teen fashion, quirky shops, and architecturally striking streets.
# - Akihabara: the epicenter of electronics and anime culture.
# - Odaiba: futuristic seaside district with views of the Rainbow Bridge and the bay.
# - Ryogoku: sumo stables and a more neighborhood feel for a slower pace.
#
# Must-see highlights
# - Shibuya Crossing and the surrounding area
# - Senso-ji Temple in Asakusa
# - Meiji Shrine and Yoyogi Park
# - Tokyo Skytree or Tokyo Tower for skyline views
# - Imperial Palace East Gardens
# - Tsukiji Outer Market or Toyosu Market for seafood and street bites
# - Ginza for shopping and upscale dining
# - TeamLab-style digital art experiences (check current venues and exact availability)
#
# Food and drink you shouldn’t miss
# - Sushi breakfast or lunch at reputable spots near Tsukiji/Toyosu
# - Ramen in neighborhoods like Ikebukuro, Tokyo Station area, or specialized shops in every ward
# - Tempura, tonkatsu, and yakitori in specialized eateries
# - Izakaya hopping in neighborhood bars for a casual evening
# - Depachika experiences in department stores (food halls with a huge variety of bites)
#
# Getting around
# - Use the JR Yamanote Line to circle the major districts (Shibuya, Shinjuku, Ikebukuro, Tokyo Station).
# - Get a Suica or PASMO card for easy tap-to-enter on subways and buses.
# - Consider a Tokyo Subway Ticket for a few days if you plan heavy metro use.
#
# Best time to visit and seasonal highlights
# - Spring (late March–April): cherry blossoms in many parks and riverside streets.
# - Autumn (October–November): pleasant weather and autumn foliage in parks and gardens.
# - Winter (December–February): fewer crowds, festive lights, and great hotel deals.
# - Summer (June–August): hot and humid, but summer festivals and fireworks are spectacular.
# - Typhoon season can bring rain in late summer/early autumn, so plan with flexible days.
#
# Day trips and nearby escapes
# - Nikko: ornate shrines set in a forested mountain landscape.
# - Hakone: hot springs, art museums, and views of Mt. Fuji.
# - Kamakura: giant Buddha statue and coastal temples.
# - Fuji Five Lakes area for closer views of Mt. Fuji.
# - Enoshima or Yokohama for coastal vibes and different flavors of urban life.
#
# Where to stay (quick guidance by vibe)
# - First-timer in the heart of action: Shinjuku or Shibuya for easy transport and nightlife.
# - Design-forward and upscale: Ginza or Omotesando.
# - Traditional charm with quieter lanes: Kagurazaka or Yanaka.
# - Waterfront/family-friendly: Odaiba.
#
# A simple 3–4 day sample vibe
# - Day 1: Shibuya and Harajuku, Meiji Shrine, Meiji Jingu Gaien, evening in Shinjuku.
# - Day 2: Asakusa (Senso-ji), Tokyo Skytree views, Akihabara for electronics/otaku culture.
# - Day 3: Imperial Palace Gardens, Ginza shopping and depachika lunch, a traditional izakaya dinner.
# - Day 4: Day trip to Nikko or Kamakura or a Hakone/Fuji day trip option.
#
# Would you like me to tailor a Tokyo plan to your trip length, dates, budget, and interests (food, history, shopping, nature, pop culture, or a mix)? If you share your preferences, I can craft a personalized itinerary with a day-by-day schedule, neighborhood picks, and dining recommendations.

# %% [markdown]
# ## Summary
#
# In this lesson you learned how to:
#
# - **Create a provider** that connects to Azure AI Foundry Agent Service via `AzureAIProjectAgentProvider`.
# - **Define a tool** using the `@tool` decorator so the agent can call your Python functions.
# - **Run the agent** with a user message and print its response.
# - **Stream responses** for real-time output.
#
# In the next lesson we will explore agentic frameworks in more depth and learn how to give agents more powerful tools and multi-step reasoning capabilities.
