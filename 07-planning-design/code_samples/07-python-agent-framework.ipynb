# %% [markdown]
# # Lesson 07 - Planning Design Pattern
#
# This notebook demonstrates the **Planning Design Pattern** for AI agents using the Microsoft Agent Framework.
# You will learn how to break complex travel requests into structured subtasks, assign them to specialist agents,
# and execute the resulting plan — all using structured output powered by Pydantic models.

# %% [markdown]
# ## Setup

# %%
! pip install agent-framework azure-ai-projects azure-identity -U -q
! pip install --upgrade agent-framework --pre
# Out:
# Requirement already satisfied: agent-framework in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: agent-framework-core==1.0.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.15.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (1.2.2)
# Requirement already satisfied: opentelemetry-api<2,>=1.39.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (1.40.0)
# Requirement already satisfied: mcp<2,>=1.24.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.27.0)
# Requirement already satisfied: agent-framework-a2a in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-ag-ui in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-azure-ai-search in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-azure-cosmos in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-anthropic in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-openai in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0)
# Requirement already satisfied: agent-framework-claude in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-azurefunctions in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-bedrock in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-chatkit in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-copilotstudio in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-declarative in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-devui in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-durabletask in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-foundry in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0)
# Requirement already satisfied: agent-framework-foundry-local in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-github-copilot in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-lab in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-ollama in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-orchestrations in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-purview in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: agent-framework-redis in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b260402)
# Requirement already satisfied: anyio>=4.5 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (4.13.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (3.3.4)
# Requirement already satisfied: starlette>=0.27 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.41.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from opentelemetry-api<2,>=1.39.0->agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2,>=1.39.0->agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core==1.0.0->agent-framework-core[all]==1.0.0->agent-framework) (2.41.5)
# Requirement already satisfied: idna>=2.8 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (3.11)
# Requirement already satisfied: certifi in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (0.30.0)
# Requirement already satisfied: cryptography>=3.4.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (46.0.6)
# Requirement already satisfied: cffi>=2.0.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (2.0.0)
# Requirement already satisfied: pycparser in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (3.0)
# Requirement already satisfied: click>=7.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.0->agent-framework) (8.3.2)
# Requirement already satisfied: a2a-sdk<0.3.24,>=0.3.5 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (0.3.23)
# Requirement already satisfied: google-api-core>=1.26.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (2.30.2)
# Requirement already satisfied: protobuf>=5.29.5 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (6.33.6)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (1.74.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (1.27.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (2.49.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (2.33.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (2.6.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0->agent-framework) (0.6.3)
# Requirement already satisfied: ag-ui-protocol==0.1.13 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (0.1.13)
# Requirement already satisfied: fastapi<0.133.1,>=0.115.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (0.133.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from fastapi<0.133.1,>=0.115.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (0.7.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0->agent-framework) (16.0)
# Requirement already satisfied: anthropic<0.80.1,>=0.80.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-anthropic->agent-framework-core[all]==1.0.0->agent-framework) (0.80.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.0->agent-framework) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.0->agent-framework) (0.17.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.0->agent-framework) (0.13.0)
# Requirement already satisfied: sniffio in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.0->agent-framework) (1.3.1)
# Requirement already satisfied: azure-search-documents<11.7.0b3,>=11.7.0b2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0->agent-framework) (11.7.0b2)
# Requirement already satisfied: azure-core>=1.28.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-search-documents<11.7.0b3,>=11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0->agent-framework) (1.39.0)
# Requirement already satisfied: azure-common>=1.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-search-documents<11.7.0b3,>=11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0->agent-framework) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-search-documents<11.7.0b3,>=11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0->agent-framework) (0.7.2)
# Requirement already satisfied: azure-cosmos<5,>=4.3.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-azure-cosmos->agent-framework-core[all]==1.0.0->agent-framework) (4.15.0)
# Requirement already satisfied: azure-functions<2,>=1.24.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.24.0)
# Requirement already satisfied: azure-functions-durable<2,>=1.3.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.5.0)
# Requirement already satisfied: werkzeug~=3.1.3 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-functions<2,>=1.24.0->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (3.1.8)
# Requirement already satisfied: aiohttp>=3.13.3 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (3.13.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (2.9.0.post0)
# Requirement already satisfied: furl>=2.1.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (2.1.4)
# Requirement already satisfied: opentelemetry-sdk>=1.32.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.40.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from werkzeug~=3.1.3->azure-functions<2,>=1.24.0->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.23.0)
# Requirement already satisfied: six>=1.8.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from furl>=2.1.0->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.17.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from furl>=2.1.0->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (1.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.32.1->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0->agent-framework) (0.61b0)
# Requirement already satisfied: boto3<2.0.0,>=1.35.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-bedrock->agent-framework-core[all]==1.0.0->agent-framework) (1.42.83)
# Requirement already satisfied: botocore<2.0.0,>=1.35.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-bedrock->agent-framework-core[all]==1.0.0->agent-framework) (1.42.83)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from boto3<2.0.0,>=1.35.0->agent-framework-bedrock->agent-framework-core[all]==1.0.0->agent-framework) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from boto3<2.0.0,>=1.35.0->agent-framework-bedrock->agent-framework-core[all]==1.0.0->agent-framework) (0.16.0)
# Requirement already satisfied: openai-chatkit<2.0.0,>=1.4.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (1.6.3)
# Requirement already satisfied: openai in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (2.30.0)
# Requirement already satisfied: openai-agents>=0.3.2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (0.13.4)
# Requirement already satisfied: jinja2<4,>=3.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (3.1.6)
# Requirement already satisfied: griffelib<3,>=2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (2.0.2)
# Requirement already satisfied: types-requests<3,>=2.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (2.33.0.20260402)
# Requirement already satisfied: tqdm>4 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from openai->openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.0->agent-framework) (4.67.3)
# Requirement already satisfied: claude-agent-sdk<0.1.49,>=0.1.36 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-claude->agent-framework-core[all]==1.0.0->agent-framework) (0.1.48)
# Requirement already satisfied: microsoft-agents-copilotstudio-client<0.3.2,>=0.3.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-copilotstudio->agent-framework-core[all]==1.0.0->agent-framework) (0.3.1)
# Requirement already satisfied: microsoft-agents-hosting-core==0.3.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from microsoft-agents-copilotstudio-client<0.3.2,>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.0->agent-framework) (0.3.1)
# Requirement already satisfied: microsoft-agents-activity==0.3.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.1->microsoft-agents-copilotstudio-client<0.3.2,>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.0->agent-framework) (0.3.1)
# Requirement already satisfied: powerfx<0.0.35,>=0.0.32 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-declarative->agent-framework-core[all]==1.0.0->agent-framework) (0.0.34)
# Requirement already satisfied: pythonnet==3.0.5 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from powerfx<0.0.35,>=0.0.32->agent-framework-declarative->agent-framework-core[all]==1.0.0->agent-framework) (3.0.5)
# Requirement already satisfied: clr_loader<0.3.0,>=0.2.7 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from pythonnet==3.0.5->powerfx<0.0.35,>=0.0.32->agent-framework-declarative->agent-framework-core[all]==1.0.0->agent-framework) (0.2.10)
# Requirement already satisfied: durabletask<2,>=1.3.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (1.3.0)
# Requirement already satisfied: durabletask-azuremanaged<2,>=1.3.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (1.3.0)
# Requirement already satisfied: grpcio in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from durabletask<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (1.80.0)
# Requirement already satisfied: asyncio in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from durabletask<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (4.0.0)
# Requirement already satisfied: packaging in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from durabletask<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (26.0)
# Requirement already satisfied: azure-identity>=1.19.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from durabletask-azuremanaged<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (1.25.3)
# Requirement already satisfied: msal>=1.35.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-identity>=1.19.0->durabletask-azuremanaged<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (1.35.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-identity>=1.19.0->durabletask-azuremanaged<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.0->agent-framework) (1.3.1)
# Requirement already satisfied: azure-ai-inference<1.0.0b10,>=1.0.0b9 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-foundry->agent-framework-core[all]==1.0.0->agent-framework) (1.0.0b9)
# Requirement already satisfied: azure-ai-projects<3.0,>=2.0.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-foundry->agent-framework-core[all]==1.0.0->agent-framework) (2.0.1)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from azure-ai-projects<3.0,>=2.0.0->agent-framework-foundry->agent-framework-core[all]==1.0.0->agent-framework) (12.28.0)
# Requirement already satisfied: foundry-local-sdk<0.5.2,>=0.5.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-foundry-local->agent-framework-core[all]==1.0.0->agent-framework) (0.5.1)
# Requirement already satisfied: github-copilot-sdk<0.1.33,>=0.1.31 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-github-copilot->agent-framework-core[all]==1.0.0->agent-framework) (0.1.32)
# Requirement already satisfied: mem0ai<2,>=1.0.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (1.0.10)
# Requirement already satisfied: posthog>=3.5.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (7.9.12)
# Requirement already satisfied: pytz>=2024.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (2026.1.post1)
# Requirement already satisfied: qdrant-client>=1.9.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (1.17.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (2.0.49)
# Requirement already satisfied: backoff>=1.10.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from posthog>=3.5.0->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (2.2.1)
# Requirement already satisfied: numpy>=1.26 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (2.4.4)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (4.1.0)
# Requirement already satisfied: greenlet>=1 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from sqlalchemy>=2.0.31->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0->agent-framework) (3.3.2)
# Requirement already satisfied: ollama<0.5.4,>=0.5.3 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-ollama->agent-framework-core[all]==1.0.0->agent-framework) (0.5.3)
# Requirement already satisfied: redis<7.2.1,>=6.4.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0->agent-framework) (7.1.1)
# Requirement already satisfied: redisvl<0.16,>=0.11.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0->agent-framework) (0.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.0->agent-framework) (1.8.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.0->agent-framework) (0.5.4)
# Requirement already satisfied: python-ulid>=3.0.0 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.0->agent-framework) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in /home/ncheng/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.0->agent-framework) (9.1.4)

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os, asyncio
from typing import Annotated
from pydantic import BaseModel
from agent_framework import tool
# from agent_framework.azure import AzureAIProjectAgentProvider
from agent_framework_foundry import FoundryAgent
from azure.identity import AzureCliCredential

# %%
# provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())
# Out:
# /tmp/ipykernel_11669/3372855538.py:1: DeprecationWarning: AzureAIProjectAgentProvider is deprecated. Use FoundryAgent instead.
#   provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %% [markdown]
# ## Task Decomposition
#
# Task decomposition is the core of the planning design pattern. Instead of asking a single agent to
# handle a complex request end-to-end, we break the problem into smaller, well-defined **subtasks**.
# Each subtask is assigned to a specialist agent (e.g., flights, hotels, activities) with clear
# priorities and dependency ordering.
#
# This approach provides several benefits:
# - **Clarity**: each subtask has a single responsibility.
# - **Parallelism**: independent subtasks can run concurrently.
# - **Reliability**: failures are isolated to individual subtasks.
# - **Budget tracking**: costs are estimated per subtask and rolled up.

# %%
class TravelSubTask(BaseModel):
    task_id: int
    description: str
    assigned_agent: str  # "flight_agent", "hotel_agent", "activity_agent"
    priority: str  # "high", "medium", "low"
    dependencies: list[int] = []


class TravelPlan(BaseModel):
    destination: str
    trip_duration_days: int
    subtasks: list[TravelSubTask]
    total_estimated_budget_usd: int
    notes: str

# %% [markdown]
# ## Creating a Planning Agent with Structured Output
#
# The planning agent acts as a **front desk coordinator**. Given a high-level travel request it
# produces a structured `TravelPlan` — decomposing the request into subtasks, setting priorities,
# and identifying dependencies so that a concierge or execution layer can carry out the work.

# %%
planning_agent = agent = FoundryAgent(
# planning_agent = await provider.create_agen(
    agent_name="TravelPlanner",
    instructions="""You are a travel planning agent. When given a travel request:
1. Break it into specific subtasks (flights, hotels, activities, logistics)
2. Assign each subtask to the appropriate specialist agent
3. Set priorities and identify dependencies between tasks
4. Estimate the total budget""",
    credential=AzureCliCredential()
)

result = await planning_agent.run(
    "Plan a 7-day trip to Paris for a couple interested in art, cuisine, and history. Budget around $5000.",
    )
if result:
    plan = result
    print(f"Destination: {plan.destination}")
    print(f"Duration: {plan.trip_duration_days} days")
    print(f"Budget: ${plan.total_estimated_budget_usd}")
    print(f"\nSubtasks:")
    for task in plan.subtasks:
        print(f"  [{task.priority}] {task.task_id}. {task.description} → {task.assigned_agent}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 planning_agent = agent = FoundryAgent(
#       2 # planning_agent = await provider.create_agen(
#       3     agent_name="TravelPlanner",
#       4     instructions="""You are a travel planning agent. When given a travel request:
#       5 1. Break it into specific subtasks (flights, hotels, activities, logistics)
#       6 2. Assign each subtask to the appropriate specialist agent
#       7 3. Set priorities and identify dependencies between tasks
#       8 4. Estimate the total budget""",
#       9     credential=AzureCliCredential()
#      10 )
#      12 result = await planning_agent.run(
#      13     "Plan a 7-day trip to Paris for a couple interested in art, cuisine, and history. Budget around $5000.",
#      14     )
#      15 if result:
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework_foundry/_agent.py:713, in FoundryAgent.__init__(self, project_endpoint, agent_name, agent_version, credential, project_client, allow_preview, tools, context_providers, middleware, client_type, env_file_path, env_file_encoding, id, name, description, instructions, default_options, require_per_service_call_history_persistence, function_invocation_configuration, compaction_strategy, tokenizer, additional_properties)
#     660 def __init__(
#     661     self,
#     662     *,
#    (...)    684     additional_properties: Mapping[str, Any] | None = None,
#     685 ) -> None:
#     686     """Initialize a Foundry Agent with full middleware and telemetry.
#     687
#     688     Keyword Args:
#    (...)    711         additional_properties: Additional properties stored on the local agent wrapper.
#     712     """
# --> 713     super().__init__(
#     714         project_endpoint=project_endpoint,
#     715         agent_name=agent_name,
#     716         agent_version=agent_version,
#     717         credential=credential,
#     718         project_client=project_client,
#     719         allow_preview=allow_preview,
#     720         tools=tools,
#     721         context_providers=context_providers,
#     722         middleware=middleware,
#     723         client_type=client_type,
#     724         env_file_path=env_file_path,
#     725         env_file_encoding=env_file_encoding,
#     726         id=id,
#     727         name=name,
#     728         description=description,
#     729         instructions=instructions,
#     730         default_options=default_options,
#     731         require_per_service_call_history_persistence=require_per_service_call_history_persistence,
#     732         function_invocation_configuration=function_invocation_configuration,
#     733         compaction_strategy=compaction_strategy,
#     734         tokenizer=tokenizer,
#     735         additional_properties=additional_properties,
#     736     )
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework/_middleware.py:1159, in AgentMiddlewareLayer.__init__(self, middleware, *args, **kwargs)
#    1157 self._cached_agent_middleware_pipeline: AgentMiddlewarePipeline | None = None
#    1158 # Pass middleware to super so BaseAgent can store it for dynamic rebuild
# -> 1159 super().__init__(*args, middleware=middleware, **kwargs)
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework/observability.py:1499, in AgentTelemetryLayer.__init__(self, otel_agent_provider_name, otel_provider_name, *args, **kwargs)
#    1495 """Initialize telemetry attributes and histograms."""
#    1496 self.otel_provider_name = (
#    1497     otel_agent_provider_name or otel_provider_name or getattr(self, "AGENT_PROVIDER_NAME", "unknown")
#    1498 )
# -> 1499 super().__init__(*args, **kwargs)
#    1500 self.token_usage_histogram = _get_token_usage_histogram()
#    1501 self.duration_histogram = _get_duration_histogram()
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework_foundry/_agent.py:544, in RawFoundryAgent.__init__(self, project_endpoint, agent_name, agent_version, credential, project_client, allow_preview, tools, context_providers, middleware, client_type, env_file_path, env_file_encoding, id, name, description, instructions, default_options, require_per_service_call_history_persistence, function_invocation_configuration, compaction_strategy, tokenizer, additional_properties)
#     539         raise TypeError(
#     540             "function_invocation_configuration requires a FunctionInvocationLayer-based client_type."
#     541         )
#     542     client_kwargs["function_invocation_configuration"] = function_invocation_configuration
# --> 544 client = actual_client_type(**client_kwargs)
#     546 super().__init__(
#     547     client=client,  # type: ignore[arg-type]
#     548     instructions=instructions,
#    (...)    559     additional_properties=dict(additional_properties) if additional_properties is not None else None,
#     560 )
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework_foundry/_agent.py:421, in _FoundryAgentChatClient.__init__(self, project_endpoint, agent_name, agent_version, credential, project_client, allow_preview, default_headers, env_file_path, env_file_encoding, instruction_role, compaction_strategy, tokenizer, additional_properties, middleware, function_invocation_configuration)
#     383 def __init__(
#     384     self,
#     385     *,
#    (...)    400     function_invocation_configuration: FunctionInvocationConfiguration | None = None,
#     401 ) -> None:
#     402     """Initialize a Foundry Agent client with full middleware support.
#     403
#     404     Keyword Args:
#    (...)    419         function_invocation_configuration: Optional function invocation configuration.
#     420     """
# --> 421     super().__init__(
#     422         project_endpoint=project_endpoint,
#     423         agent_name=agent_name,
#     424         agent_version=agent_version,
#     425         credential=credential,
#     426         project_client=project_client,
#     427         allow_preview=allow_preview,
#     428         default_headers=default_headers,
#     429         env_file_path=env_file_path,
#     430         env_file_encoding=env_file_encoding,
#     431         instruction_role=instruction_role,
#     432         compaction_strategy=compaction_strategy,
#     433         tokenizer=tokenizer,
#     434         additional_properties=additional_properties,
#     435         middleware=middleware,
#     436         function_invocation_configuration=function_invocation_configuration,
#     437     )
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework/_tools.py:2061, in FunctionInvocationLayer.__init__(self, middleware, function_invocation_configuration, **kwargs)
#    2059 if (chat_middleware := (middleware_list["chat"] or None)) is not None:
#    2060     kwargs["middleware"] = chat_middleware
# -> 2061 super().__init__(**kwargs)
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework/_middleware.py:1007, in ChatMiddlewareLayer.__init__(self, middleware, **kwargs)
#    1005 self.chat_middleware = list(middleware) if middleware else []
#    1006 self._cached_chat_middleware_pipeline: ChatMiddlewarePipeline | None = None
# -> 1007 super().__init__(**kwargs)
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework/observability.py:1181, in ChatTelemetryLayer.__init__(self, otel_provider_name, *args, **kwargs)
#    1179 def __init__(self, *args: Any, otel_provider_name: str | None = None, **kwargs: Any) -> None:
#    1180     """Initialize telemetry attributes and histograms."""
# -> 1181     super().__init__(*args, **kwargs)
#    1182     self.token_usage_histogram = _get_token_usage_histogram()
#    1183     self.duration_histogram = _get_duration_histogram()
#
# File ~/repos/ai-agents-for-beginners/.venv/lib/python3.12/site-packages/agent_framework_foundry/_agent.py:182, in RawFoundryAgentChatClient.__init__(self, project_endpoint, agent_name, agent_version, credential, project_client, allow_preview, default_headers, env_file_path, env_file_encoding, instruction_role, compaction_strategy, tokenizer, additional_properties)
#     180 else:
#     181     if not resolved_endpoint:
# --> 182         raise ValueError(
#     183             "Either 'project_endpoint' or 'project_client' is required. "
#     184             "Set project_endpoint via parameter or 'FOUNDRY_PROJECT_ENDPOINT' environment variable."
#     185         )
#     186     if not credential:
#     187         raise ValueError("Azure credential is required when using project_endpoint without a project_client.")
#
# ValueError: Either 'project_endpoint' or 'project_client' is required. Set project_endpoint via parameter or 'FOUNDRY_PROJECT_ENDPOINT' environment variable.

# %% [markdown]
# ## Executing a Plan with Specialist Tools
#
# Once the front desk agent has produced a structured plan, the **concierge agent** executes it.
# Each specialist tool handles one category of subtask (flights, hotels, activities). The concierge
# iterates through the plan's subtasks in dependency order and dispatches each one to the
# appropriate tool.

# %%
@tool
def book_flight(
    destination: Annotated[str, "The destination city"],
    departure_date: Annotated[str, "Departure date (YYYY-MM-DD)"],
    return_date: Annotated[str, "Return date (YYYY-MM-DD)"],
) -> str:
    """Search and book flights for the trip."""
    return f"Flight booked to {destination}: {departure_date} → {return_date}, confirmation #FLT-{hash(destination) % 10000:04d}"


@tool
def reserve_hotel(
    city: Annotated[str, "The city for the hotel"],
    check_in: Annotated[str, "Check-in date (YYYY-MM-DD)"],
    check_out: Annotated[str, "Check-out date (YYYY-MM-DD)"],
    guests: Annotated[int, "Number of guests"],
) -> str:
    """Reserve a hotel room in the destination city."""
    return f"Hotel reserved in {city}: {check_in} to {check_out} for {guests} guests, confirmation #HTL-{hash(city) % 10000:04d}"


@tool
def book_activity(
    activity_name: Annotated[str, "Name of the activity or tour"],
    date: Annotated[str, "Date of the activity (YYYY-MM-DD)"],
    participants: Annotated[int, "Number of participants"],
) -> str:
    """Book a tour, museum visit, or other activity."""
    return f"Activity booked: {activity_name} on {date} for {participants} people, confirmation #ACT-{hash(activity_name) % 10000:04d}"


# Concierge agent that executes the plan using specialist tools
concierge_agent = await provider.create_agent(
    name="Concierge",
    instructions="""You are a travel concierge executing a structured travel plan.
Use the available tools to fulfil each subtask. Work through the subtasks in order,
respecting dependencies. Summarise the results when finished.""",
    tools=[book_flight, reserve_hotel, book_activity],
)

# Build a prompt from the plan produced above
if result.value:
    subtask_lines = "\n".join(
        f"- [{t.priority}] {t.task_id}. {t.description} (agent: {t.assigned_agent}, deps: {t.dependencies})"
        for t in plan.subtasks
    )
    execution_prompt = (
        f"Execute the following travel plan for {plan.destination} "
        f"({plan.trip_duration_days} days, ${plan.total_estimated_budget_usd} budget):\n"
        f"{subtask_lines}"
    )

    exec_response = await concierge_agent.run(execution_prompt)
    print(exec_response)

# %% [markdown]
# ## Summary
#
# In this lesson you learned the **Planning Design Pattern** for AI agents:
#
# 1. **Task Decomposition** — A front desk planning agent breaks a complex travel request into
#    structured subtasks using Pydantic models, assigning each to a specialist agent with priorities
#    and dependencies.
# 2. **Structured Output** — By passing a `response_format` the agent returns a validated
#    `TravelPlan` object instead of free-form text, making downstream processing reliable.
# 3. **Plan Execution** — A concierge agent iterates through the subtasks using specialist tools
#    (`book_flight`, `reserve_hotel`, `book_activity`) to carry out the plan and report results.
#
# This pattern separates *what to do* (planning) from *how to do it* (execution), making agents
# more modular, testable, and easier to extend.
