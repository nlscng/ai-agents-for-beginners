# %% [markdown]
# # Lesson 10 - AI Agents in Production
#
# In this lesson you will learn **production patterns** for AI agents using the Microsoft Agent Framework (Python). We cover:
#
# - **Observability** — adding timing and logging to agent interactions
# - **Evaluation** — using an evaluator agent to score response quality
# - **Cost management** — strategies for token optimization and model selection
#
# The scenario is a **travel agent** that helps users plan trips, with monitoring and evaluation layered on top.

# %% [markdown]
# ## Setup

# %%
! pip install agent-framework agent-framework-foundry azure-ai-projects azure-identity python-dotenv -U -q

# %%
import logging

import os
import asyncio
import time
from typing import Annotated

from agent_framework import tool
from agent_framework_foundry import FoundryChatClient
from azure.identity import AzureCliCredential

from dotenv import load_dotenv
load_dotenv("../../.env")
# Out:
# True

# %%
# Create the FoundryChatClient
client = FoundryChatClient(
    credential=AzureCliCredential(),
    model=os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o"),
)

# %% [markdown]
# ## Production Considerations
#
# Moving AI agents from prototypes to production requires careful attention to three pillars:
#
# 1. **Observability** — You need visibility into what the agent is doing, how long it takes, and which tools it calls. Without tracing and logging, debugging production issues is nearly impossible.
#
# 2. **Evaluation** — Automated quality checks ensure the agent's responses remain accurate, complete, and helpful over time. An evaluator agent can score responses against defined criteria.
#
# 3. **Cost Management** — Token usage directly impacts cost. Strategies like prompt optimization, model selection, and caching help keep expenses under control without sacrificing quality.

# %% [markdown]
# ## Building an Observable Agent
#
# We define travel tools and wrap the agent call with timing so we can monitor latency. In production you would integrate with OpenTelemetry or a similar tracing backend.

# %%
@tool(approval_mode="never_require")
def get_flight_info(destination: Annotated[str, "The destination city"]) -> str:
    """Get flight information for a destination."""
    flights = {
        "Paris": "BA 304, 08:30-11:45, $350",
        "Tokyo": "JL 044, 11:00-07:00+1, $890",
        "Barcelona": "VY 7821, 07:15-10:30, $280",
    }
    return flights.get(destination, f"No flights found to {destination}")


@tool(approval_mode="never_require")
def get_activity_suggestions(destination: Annotated[str, "The destination city"]) -> str:
    """Get activity suggestions for a destination."""
    activities = {
        "Paris": "Louvre Museum, Eiffel Tower, Seine River Cruise, Montmartre walking tour",
        "Tokyo": "Senso-ji Temple, Tsukiji Market tour, Shibuya Crossing, teamLab Borderless",
        "Barcelona": "Sagrada Familia, Park Güell, La Boqueria Market, Gothic Quarter walk",
    }
    return activities.get(destination, f"No activities found for {destination}")

# %%
agent = client.as_agent(
    tools=[get_flight_info, get_activity_suggestions],
    name="TravelAgent",
    instructions="You are a helpful travel agent. Use the available tools to help users plan their trips. Provide comprehensive, actionable travel advice.",
)

# Simple observability: track timing
start_time = time.time()
response = await agent.run(
    "I want to plan a day trip in Paris. What flights and activities do you recommend?",
    )
elapsed = time.time() - start_time
print(f"Response ({elapsed:.2f}s):\n{response}")
# Out:
# Response (50.64s):
# Fantastic idea. Here’s a practical day-trip plan to make the most of Paris, given you’ve got a morning arrival by BA 304 (08:30–11:45) for about $350.
#
# Important note about Louvre: If your plan is for today, Louvre is typically closed on Tuesdays. Since today is Tue, Apr 21, 2026, I’ve tailor-made the plan without Louvre. If you want Louvre on a different day, I can adjust.
#
# Flight summary
# - inbound: BA 304, 08:30–11:45, approx. $350
# - next steps: I can help you book a return flight and reserve timed-entry tickets for Eiffel Tower and a Seine cruise if you’d like.
#
# Day-trip plan (Tuesday) – icons plus a relaxed pace
# Aim: See Paris highlights without backtracking too much. This version centers on Eiffel Tower, Seine cruise, and Montmartre.
#
# Option A: Eiffel Tower + Seine cruise + Montmartre
# - 12:15–13:15: Transit from the airport to central Paris and drop bags if needed; quick lunch near your first stop (Trocadéro area has good options with great views of the tower).
# - 13:30–15:15: Eiffel Tower visit (top-tier tickets are best to pre-book; if you’d rather skip the long lines, just enjoy the views from the Trocadéro or 2nd floor). Plan 1.5 hours.
# - 15:30–16:30: Seine River Cruise (1 hour) to relax and see major sights from the water.
# - 17:00–18:30: Montmartre walking explore Sacré-Cœur, place du Tertre, and the bohemian vibe.
# - 19:00–20:30: Dinner in Montmartre or nearby Saint-Germain/Le Marais depending on mood.
# - 20:30–Optional: Quick nighttime stroll along the Seine or a rooftop view if you’re not tired.
#
# Option B: If you’d rather swap in an art museum open on Tuesdays (instead of Louvre)
# - 12:15–13:15: Lunch near the Seine
# - 13:30–15:15: Musée d’Orsay (Impressionist masterpieces; open Tue, good for a culture-heavy afternoon)
# - 15:30–16:30: Seine River Cruise (1 hour)
# - 17:00–18:45: Montmartre exploration (Sacré-Cœur, artists’ square)
# - 19:00–20:30: Dinner in Montmartre or nearby
# - 20:30–Optional: Night views from Montmartre or a short evening stroll along the river
#
# Notes to maximize the day
# - Louvre is closed on Tuesdays, so Options A and B keep your day rich without waiting in Louvre lines.
# - Pre-booking tips:
#   - Eiffel Tower: book skip-the-line tickets for your preferred time window.
#   - Seine cruise: choose a depart time that fits after your Eiffel/Tower time; many cruises start near the Eiffel Tower area or Île de la Cité.
#   - Musée d’Orsay: if you go Option B, book a timed-entry to avoid lines.
# - Transit tips:
#   - From CDG to central Paris: RER B to Châtelet-Lénais-Les Halles or Gare du Nord, depending on your hotel. Expect 35–60 minutes, plus time to collect bags.
#   - Getting around: Paris Metro and buses are efficient; consider a 1-day Navigo pass or a contactless card for quick transfers.
# - Food tips:
#   - Quick lunch options around Trocadéro or Île de la Cité; great pastries and bistros in Montmartre for dinner.
#   - If you want a classic Parisian bistro experience, reserve a dinner spot in Montmartre or Saint-Germain.
#
# What I can do next for you
# - Book the exact timed-entry tickets: Eiffel Tower, Seine cruise, and Orsay if you choose Option B.
# - Suggest a precise route with ride times between stops based on your hotel location.
# - Look up a return flight or extend your stay if you want a fuller Paris day.
# - Provide restaurant recommendations tailored to your budget and cuisine preferences.
#
# Quick questions to tailor this perfectly
# - Do you want me to reserve Eiffel Tower tickets and a Seine cruise now?
# - Are you staying near a particular neighborhood (e.g., near the Louvre, Champs-Élysées, Montmartre)?
# - Would you prefer Option A (iconic sights first) or Option B (Orsay first) given the Tuesday Louvre closure?
#
# If you’d like, tell me your hotel area in Paris and your preferred time for the Eiffel Tower visit, and I’ll lock in the exact timetable and book everything.

# %% [markdown]
# ## Evaluation Patterns
#
# A common production pattern is to use a second agent as an **evaluator**. The evaluator scores the primary agent's response against predefined criteria such as completeness, accuracy, and helpfulness.
#
# This enables:
# - Automated quality gates before responses reach users
# - Regression detection when prompts or models change
# - Continuous monitoring of agent performance over time

# %%
evaluator = client.as_agent(
    name="ResponseEvaluator",
    instructions="""You evaluate travel agent responses on these criteria:
1. Completeness (1-5): Did it cover flights AND activities?
2. Accuracy (1-5): Is the information consistent?
3. Helpfulness (1-5): Would a traveler find this actionable?
4. Overall Score (1-5)
Provide scores and a brief explanation for each.""",
)

evaluation = await evaluator.run(f"Evaluate this travel agent response:\n\n{response}")
print(f"Evaluation:\n{evaluation}")
# Out:
# Evaluation:
# ### 1. Completeness (5/5)
# The response fully covers flights (inbound details, return offers, and booking assistance) and activities (detailed itineraries with options, timed plans, alternatives for the Louvre closure, plus transit, food, and pre-booking tips), leaving no major gaps for a day-trip query.
#
# ### 2. Accuracy (5/5)
# All information is consistent and factually sound: correct date (Tuesday, April 21, 2026), Louvre closure on Tuesdays, Musée d’Orsay openness, realistic flight/transit times, and practical Paris logistics like RER B and Navigo passes align with real-world details.
#
# ### 3. Helpfulness (5/5)
# Highly actionable with tailored options, step-by-step plans, proactive booking offers, and specific questions to customize further; a traveler could immediately use this to plan or book, adapting seamlessly to constraints like the museum closure.
#
# ### 4. Overall Score (5/5)
# An outstanding, comprehensive response that's engaging, adaptive, and customer-focused, turning a simple query into a ready-to-execute itinerary.

# %% [markdown]
# ## Cost Management Strategies
#
# Controlling costs is critical for production AI agents. Here are key strategies:
#
# | Strategy | Description |
# |---|---|
# | **Prompt optimization** | Keep system instructions concise. Remove redundant context to reduce input tokens. |
# | **Model selection** | Use smaller, cheaper models (e.g. GPT-4o-mini) for simple tasks like classification or extraction, and reserve larger models for complex reasoning. |
# | **Caching** | Cache tool results and frequent queries to avoid redundant API calls. |
# | **Token budgets** | Set `max_tokens` limits to prevent unexpectedly long responses. |
# | **Batching** | Group multiple user queries into a single API call where possible. |
#
# In practice, a tiered approach works well: route straightforward requests to a fast, inexpensive model and escalate only complex queries to a more capable one.

# %% [markdown]
# ## Summary
#
# In this lesson you learned how to:
#
# 1. **Add observability** to agent interactions with timing and logging, laying the groundwork for tracing and monitoring.
# 2. **Evaluate agent responses** automatically using an evaluator agent that scores completeness, accuracy, and helpfulness.
# 3. **Manage costs** through prompt optimization, model selection, caching, and token budgets.
#
# These production patterns help ensure your AI agents are reliable, measurable, and cost-effective at scale.
