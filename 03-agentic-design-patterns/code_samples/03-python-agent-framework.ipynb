# %% [markdown]
# # Lesson 03 - Agentic Design Patterns
#
# In this lesson, we explore three foundational design patterns for building effective AI agents:
#
# 1. **Clear Agent Instructions** — Crafting precise, role-defining prompts that guide agent behavior
# 2. **Structured Output with Pydantic Models** — Ensuring agents return predictable, validated data
# 3. **Single Responsibility Agents** — Designing focused agents that each do one thing well
#
# We'll apply each pattern to a **travel destination recommender** scenario, progressively building a system that can suggest destinations, check availability, and handle logistics.

# %% [markdown]
# ## Setup

# %%
# %pip install agent-framework azure-ai-projects azure-identity pydantic --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os
import asyncio
from typing import Annotated
from pydantic import BaseModel
from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %% [markdown]
# ## Pattern 1: Clear Agent Instructions
#
# The most impactful pattern is also the simplest: writing clear, detailed instructions for your agent.
#
# Good instructions define:
# - **Who** the agent is (persona and tone)
# - **What** it should do (step-by-step responsibilities)
# - **How** it should behave (constraints and style)
#
# Below, we create a travel concierge agent with explicit instructions that shape every response it produces.

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

agent = await provider.create_agent(
    name="TravelConcierge",
    instructions="""You are a luxury travel concierge named Alex. Your role is to:
1. Understand the traveler's preferences (budget, climate, activities)
2. Check destination availability before making recommendations
3. Provide detailed, personalized travel suggestions
4. Always mention visa requirements and best travel seasons
Be warm, professional, and enthusiastic about travel.""",
)

response = await agent.run(
    "I'd love a week-long vacation somewhere with great food and history. Budget around $2500."
)
print(response)
# Out:
# Hello! I’m Alex, your luxury travel concierge. I love helping travelers with great food and fascinating history. With a week and a budget around $2,500, there are several wonderful options that balance culture, cuisine, and comfort. I can check live availability as soon as you share your departure city and your dates, but here are four strong contenders that tend to fit your budget well and deliver rich experiences.
#
# Option 1: Mexico City, Mexico
# - Why it suits you: A world-class culinary scene (tasting menus and street-food gems alike) paired with centuries of history—from ancient ruins in nearby Teotihuacan to colonial architecture in the historic center.
# - Best travel season: November through April (drier, mild weather).
# - Rough budget breakdown (7 nights):
#   - Flights: from many U.S. cities around $350–$600 round trip (prices vary by origin and dates).
#   - Hotels: charming boutique to luxury accommodations around $180–$230 per night → roughly $1,260–$1,610.
#   - Experiences/food: chef’s table or guided food tours, museum admissions, day trips → $350–$600.
#   - Estimated total: roughly $2,000–$2,800 depending on choices.
# - Sample 7-day itinerary (highlights):
#   - Day 1: Arrival and classic CDMX dinner in Roma/Condesa.
#   - Day 2: Historic Center (Zócalo, Catedral, Templo Mayor) + National Palace murals; evening mezcal tasting.
#   - Day 3: Teotihuacan sunrise (private guide) with a gourmet lunch back in the city.
#   - Day 4: Frida Kahlo Museum (Coyoacán) + San Ángel Market; sunset at a fine dining restaurant.
#   - Day 5: Day trip to Puebla or Taxco for history and architecture.
#   - Day 6: Xochimilco canal ride + food tour or cooking class.
#   - Day 7: Polanco museums or a last-minute shopping spree; depart.
#
# Visa and entry notes (typical cases):
# - For many nationalities (e.g., U.S., EU), Mexico requires a short tourist permit (FMM) to be completed online or on arrival; passport validity rules apply. I’ll confirm exact requirements once I know your nationality.
# - Best season: as above (Nov–Apr for comfortable weather).
#
# Option 2: Lisbon, Portugal (plus a day trip to Sintra)
# - Why it suits you: A culinary paradise with a long, layered history—from Moorish influence to maritime explorers. Amazing seafood, pasteis de nata, and hillside neighborhoods with timeless charm.
# - Best travel season: March–May and September–October (pleasant weather, fewer crowds).
# - Rough budget breakdown (7 nights):
#   - Flights: roughly $500–$800 from many origins.
#   - Hotels: boutique to 4-5 star around $180–$250 per night → roughly $1,260–$1,750.
#   - Experiences/food: guided food tours, Fado evening, day trip to Sintra, wine/taste experiences → $350–$600.
#   - Estimated total: around $2,100–$2,900 (possible to keep closer to $2,500 with selective choices).
# - Sample 7-day itinerary:
#   - Day 1: Alfama stroll, dinner with a view.
#   - Day 2: Belém cultural sights (Jerónimos Monastery, Pasteis de Belém) + great seafood lunch.
#   - Day 3: Sintra day trip (Pena Palace, Quinta da Regaleira).
#   - Day 4: Baixa/Chiado neighborhoods, Time Out Market for a tasting menu.
#   - Day 5: Cascais or Estoril coast day trip; sunset by the coast.
#   - Day 6: Cooking class focusing on Portuguese cuisine + wine tasting.
#   - Day 7: Museum day or a final neighborhood food tour; depart.
# - Visa note:
#   - For many nationalities, Portugal is visa-free for short stays under Schengen rules (up to 90 days). If you’re not a national from a visa-exempt country, I’ll check exact rules for you once I know your nationality.
#
# Option 3: Istanbul, Turkey
# - Why it suits you: A museum-filled, food-rich city bridging Europe and Asia, with markets, Ottoman palaces, and incredible Turkish cuisine.
# - Best travel season: April–May and September–October (milder temps, lighter crowds).
# - Rough budget breakdown (7 nights):
#   - Flights: roughly $650–$900 from many origins.
#   - Hotels: stylish boutiques around $120–$200 per night → $840–$1,400.
#   - Experiences/food: private tours, Bosphorus cruise, hammam, cooking class → $300–$500.
#   - Estimated total: roughly $2,000–$2,800.
# - Sample 7-day itinerary:
#   - Day 1: Sultanahmet walk (Hagia Sophia, Blue Mosque) and a rooftop dinner.
#   - Day 2: Topkapi Palace and Bosphorus cruise.
#   - Day 3: Grand Bazaar and Spice Market; Turkish cooking class.
#   - Day 4: Asian-side neighborhood exploration (Kadıköy) + street-food tasting.
#   - Day 5: Day trip to Gallipoli or Princes’ Islands (optional, time permitting).
#   - Day 6: Dolmabahçe Palace or a guided art/history day; evening in a historic hamam.
#   - Day 7: Leisure day and departure.
# - Visa note:
#   - Many nationalities can obtain an e-Visa or visa on arrival; exact rules depend on your passport. I’ll confirm once you share your nationality.
#
# Option 4: Marrakech, Morocco
# - Why it suits you: A feast for the senses—historic medinas, Berber-influenced cuisine, colorful souks, and exquisite riads for a luxurious stay.
# - Best travel season: March–May and September–November (pleasant temperatures for exploring).
# - Rough budget breakdown (7 nights):
#   - Flights: roughly $700–$1,000 from many origins.
#   - Hotels: chic riads and small luxury hotels around $150–$230 per night → $1,050–$1,610.
#   - Experiences/food: guided medina tours, cooking class, day trip to the Atlas Mountains or Essaouira → $250–$450.
#   - Estimated total: roughly $2,000–$2,900.
# - Sample 7-day itinerary:
#   - Day 1: Jemaa el-Fnaa square at sunset, camel ride option, rooftop dinner.
#   - Day 2: Bahia Palace, Saadian Tombs, and souk labyrinths.
#   - Day 3: Atlas Mountains day trip or Essaouira coastal visit.
#   - Day 4: Cooking class and market visit for fresh ingredients.
#   - Day 5: Jardin Majorelle and Yves Saint Laurent museum; spa day in a Riad.
#   - Day 6: Marrakech Palaces route or hot-air balloon ride (seasonal).
#   - Day 7: Leisure day and departure.
# - Visa note:
#   - Many nationalities can visit Morocco visa-free for short stays; I’ll confirm for yours once you share your passport details.
#
# What I’d love to know to tailor this perfectly:
# - Departure city and your target travel dates (or flexibility around them).
# - Are you leaning more toward a single-city experience or a relaxed multi-city route?
# - Type of luxury you prefer (boutique hotels with character, private tours, exclusive dining, spa experiences)?
# - Any must-have experiences (food tours, cooking classes, private guides, aristocratic palaces, ancient ruins, wine tastings, etc.)?
# - Are you comfortable with medium airfare and higher hotel rates if they deliver exceptional food/history?
#
# Next steps:
# - Share your nationality (passport) so I can confirm exact visa requirements for each destination.
# - Tell me your departure city and dates, plus any flexibility.
# - I’ll then check real-time availability and put together a detailed, day-by-day luxury week that fits your $2,500 budget as closely as possible. I can also optimize for best value by selecting 4-star boutique hotels, private tours, and curated culinary experiences.
#
# If you’d like, I can start with two solid, ready-to-book options (for example, Mexico City or Lisbon) and create a precise, live-price itinerary once you share your details. I’m excited to craft an unforgettable week of great food and history for you!

# %% [markdown]
# ## Pattern 2: Structured Output with Pydantic Models
#
# Free-form text is useful for conversation, but downstream systems need structured data.
# By pairing **Pydantic models** with a **tool function**, we can:
#
# - Define an exact schema for the agent's output
# - Validate responses automatically
# - Integrate agent results into application logic reliably
#
# We also introduce a tool that returns destination details so the agent grounds its recommendations in real data.

# %%
class DestinationRecommendation(BaseModel):
    destination: str
    available: bool
    best_season: str
    highlights: list[str]
    estimated_budget_usd: int


class TravelRecommendations(BaseModel):
    recommendations: list[DestinationRecommendation]
    personalized_note: str


@tool(approval_mode="never_require")
def get_destination_details(destination: Annotated[str, "The destination to look up"]) -> str:
    """Get details about a vacation destination."""
    details = {
        "Barcelona": "Available. Best: May-Jun. Beach, architecture, nightlife. ~$2000/week",
        "Tokyo": "Available. Best: Mar-Apr. Culture, food, technology. ~$2500/week",
        "Cape Town": "Not available. Best: Nov-Mar. Nature, wine, adventure. ~$1800/week",
    }
    return details.get(destination, f"{destination}: No information available.")


structured_agent = await provider.create_agent(
    name="StructuredTravelExpert",
    instructions="You are a travel expert. Recommend destinations based on traveler preferences. Use the get_destination_details tool.",
    tools=[get_destination_details],
)

response = await structured_agent.run(
    "Recommend 3 destinations for a culture-loving traveler with a $2500 budget"
)

if response:
    print(response)
# Out:
# Here are three culture-rich destinations that fit a $2500 travel budget (typical 7–10 day trips). They offer deep history, vibrant arts scenes, and memorable experiences without breaking the bank.
#
# 1) Istanbul, Turkey
# - Why it fits: A true crossroads of East and West with Byzantine and Ottoman wonders, grand mosques, bazaars, and a thriving contemporary arts scene.
# - What to do: Hagia Sophia, Blue Mosque, Topkapi Palace, Grand Bazaar; a Bosphorus cruise; a day trip to the princes’ islands; neighborhoods like Karaköy and Balat for food and street art.
# - Typical spend range (excluding international flight): about $60–100 per day, depending on lodging and dining choices.
# - Handy tip: Great value for history buffs; try a mix of boutique stays in neighborhoods like Cihangir or Sultanahmet and local eateries for authentic flavors.
#
# 2) Oaxaca, Mexico
# - Why it fits: Rich Indigenous cultures, colonial architecture, and a renowned culinary and arts scene. A great setting for museums, markets, and hands-on experiences (chefs, crafts, mezcal).
# - What to do: Monte Albán ruins; Santo Domingo de Guzmán church and museum district; food markets (mercados) and craft workshops; Day of the Dead festivals if timing aligns; Mezcal tastings and cooking classes.
# - Typical spend range (excluding international flight): about $40–80 per day, depending on lodging and meals.
# - Handy tip: A great value destination with excellent local cuisine; pair museum days with market strolls to keep costs down.
#
# 3) Marrakesh, Morocco
# - Why it fits: A sensory immersion into a world of color, spices, palaces, and bustling souks, plus easy access to deserts and mountains for day trips.
# - What to do: Medina and Jemaa el-Fnaa square; Bahia Palace and Saadian Tombs; souk hopping for textiles, ceramics, and lanterns; a spice-and-tea experience; a desert day trip or a ride to the Atlas Mountains.
# - Typical spend range (excluding international flight): about $50–90 per day, depending on lodging and meals. Pleasant options exist from budget riads to boutique hotels.
# - Handy tip: Negotiate in markets and opt for riads with breakfast; consider a guided tour for a safer, richer cultural experience.
#
# A few quick notes
# - Your origin and dates will affect flight costs; if you share your departure city and trip length, I can estimate a concrete budget and find good-value flight/hotel options.
# - All three destinations offer strong cultural experiences while staying within a $2500 total budget for a 7–10 day trip, especially with smart lodging choices and a focus on local experiences over splurges.
# - If you’d prefer Europe or East Asia instead, I can tailor alternatives (e.g., Seville, Spain; Prague, Czechia; or Kyoto, Japan) with a similar budget framework.
#
# Would you like me to fine-tune these options with your travel origin, travel dates, and preferred trip length? I can also pull live price ranges and sample itineraries.

# %% [markdown]
# ## Pattern 3: Single Responsibility Agents
#
# Complex tasks benefit from splitting work across multiple focused agents, each with a single responsibility:
#
# - A **Destination Expert** that knows about places and availability
# - A **Logistics Planner** that handles flights, hotels, and itineraries
#
# This mirrors the software engineering principle of *separation of concerns* — each agent is easier to test, maintain, and improve independently.

# %%
destination_agent = await provider.create_agent(
    name="DestinationExpert",
    tools=[get_destination_details],
    instructions="""You are a destination research specialist. Your only job is to:
1. Evaluate destinations based on traveler preferences
2. Check availability using the provided tool
3. Return a short ranked list with pros/cons
Do NOT discuss flights, hotels, or logistics — another agent handles that.""",
)

logistics_agent = await provider.create_agent(
    name="LogisticsPlanner",
    instructions="""You are a travel logistics planner. Your only job is to:
1. Create a day-by-day itinerary for the chosen destination
2. Suggest flight and hotel options within the stated budget
3. Note visa requirements and travel insurance recommendations
Do NOT recommend destinations — another agent handles that.""",
)

# Step 1: Destination Expert picks the best options
dest_response = await destination_agent.run(
    "I want a week of culture and food for under $2500. Where should I go?"
)
print("=== Destination Expert ===")
print(dest_response)

# Step 2: Logistics Planner builds the trip plan
logistics_response = await logistics_agent.run(
    f"Plan a week-long trip based on this recommendation:\n{dest_response}"
)
print("\n=== Logistics Planner ===")
print(logistics_response)
# Out:
# === Destination Expert ===
# Here are 5 strong options for a week focused on culture and food, all typically doable on under $2500 for a week ( excluding flights/logistics). Each has deep culinary scenes and rich cultural sights. Availability checks via the provided tool returned no information for these destinations right now, so I can re-check once you share specific dates.
#
# 1) Oaxaca, Mexico
# - Why it fits: Incredible regional cuisine (mole, siete moles, tlayudas), vibrant markets, Zapotec and Mixtec archaeology, colonial architecture.
# - Pros: Very affordable food and experiences; walkable downtown; great day trips to Monte Albán and mezcal distilleries.
# - Cons: Smaller city might feel slow for some; some sites are outside the main city.
# - Availability check: No information available from the tool.
#
# 2) Mexico City, Mexico
# - Why it fits: One of the world’s best food capitals—tacos, mercados, high-end dining, and a wealth of museums and historic neighborhoods.
# - Pros: Massive variety of cuisines and neighborhoods to explore; world-class museums and architecture; very good value if you pick mid-range stays and street-food eats.
# - Cons: Huge city can be overwhelming; air quality can vary.
# - Availability check: No information available from the tool.
#
# 3) Lima, Peru
# - Why it fits: Renowned gastronomy scene (ceviche, anticuchos, Nikkei fusion); rich colonial and pre-Columbian culture; entry point to coastal beauty and nearby ruins.
# - Pros: Excellent value for food-centric itineraries; good mix of city culture and access to top culinary experiences.
# - Cons: Longer flight for some travelers; some high-altitude excursions require extra planning if you add more sites.
# - Availability check: No information available from the tool.
#
# 4) Hanoi, Vietnam
# - Why it fits: One of the best street-food destinations in the world; strong cultural sites (Old Quarter, temples, water puppets); vibrant markets and cafe culture.
# - Pros: Remarkable value for money on food and experiences; immersive local culture; manageable pace for a week.
# - Cons: Longer travel time for many feeders; language and navigation can be challenging at first.
# - Availability check: No information available from the tool.
#
# 5) Seville, Spain
# - Why it fits: Deep Andalusian culture, tapas, flamenco, and superb Moorish-influenced architecture; strong culinary scene with wines and regional specialties.
# - Pros: High cultural density in a compact city; very walkable; good food and festive vibe.
# - Cons: Can be pricier than Mexico/Peru for some budgets, but still doable on $2500 with mid-range options and careful planning.
# - Availability check: No information available from the tool.
#
# Next steps
# - Share your travel dates, preferred pace (balanced vs. activity-packed), any dietary considerations, and whether you’d rather stay closer to urban culture or include a few day-trip excursions.
# - I’ll re-check availability with those dates and tighten these options into a short, date-appropriate 7-day itinerary with daily highlights and sample meals, staying within your $2500 target.
#
# === Logistics Planner ===
# Absolutely! I’m ready to flesh out a full 7‑day itinerary, flight‑and‑hotel plan, and the necessary visa / insurance details — but I’ll need a few specifics from you first so everything is spot‑on and fits your $2,500 budget (excluding the logistics you’ll cover).
#
# **Please let me know:**
#
# | Item | What I need from you |
# |------|----------------------|
# | **Chosen destination** | Which of the five options (Oaxaca, Mexico City, Lima, Hanoi, or Seville) are you leaning toward? |
# | **Travel dates** | Exact departure/return dates (or at least the month/week you want to travel). |
# | **Pace** | Do you prefer a relaxed, “balanced” schedule (1‑2 main activities per day) or a more activity‑packed itinerary (3+ highlights daily)? |
# | **Dietary considerations** | Any food allergies, preferences (vegetarian/vegan, gluten‑free, etc.) or particular culinary experiences you absolutely want (e.g., a cooking class, street‑food tour, fine‑dining tasting menu). |
# | **Urban vs. excursions** | Would you like the week to stay mostly in the city, or include day‑trips/out‑of‑town tours (e.g., Monte Albán from Oaxaca, Machu Picchu side‑trip from Lima, Ha Long‑bay‑style water‑puppet show in Hanoi, or Córdoba from Seville)? |
# | **Preferred travel class** | Economy, Premium Economy, or Business for the flights? |
# | **Accommodation style** | Boutique hotel, mid‑range chain, boutique guesthouse/ B&B, or a mix of city hotel + a night‑outstay in a nearby town? |
# | **Any loyalty programs** | Airline or hotel frequent‑flyer/loyalty membership you’d like to use (e.g., Marriott Bonvoy, Hilton Honors, etc.). |
#
# Once I have those details I’ll:
#
# 1. **Draft a day‑by‑day itinerary** with cultural sights, food stops, and optional excursions tuned to your pace.
# 2. **Provide flight options** (airlines, typical prices, and departure/arrival times) that stay within the $2,500 food‑and‑activities budget plus a realistic estimate for flights‑and‑accommodation.
# 3. **Suggest 2‑3 hotel/guesthouse choices** per night (including price ranges, locations, and amenities) that keep the total cost under the budget.
# 4. **List visa requirements, entry‑document needs, and recommended travel‑insurance coverage** for your nationality.
#
# Just send over the above information, and I’ll get the full plan ready for you!

# %% [markdown]
# ## Summary
#
# In this lesson we applied three agentic design patterns to a travel recommender scenario:
#
# | Pattern | Key Idea | Benefit |
# |---|---|---|
# | **Clear Instructions** | Define persona, responsibilities, and constraints up front | Consistent, on-brand agent behavior |
# | **Structured Output** | Use Pydantic models as the response format | Validated, machine-readable results |
# | **Single Responsibility** | Give each agent one focused job | Easier to test, maintain, and compose |
#
# These patterns compose naturally — you can combine clear instructions with structured output inside a single-responsibility agent to build robust, production-ready systems.
